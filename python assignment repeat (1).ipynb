# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
file_path = r'C:\Users\navee\Downloads\aa.csv'  # Replace with your actual file path #
df = pd.read_csv(file_path, skiprows=4)

# %%
countries = ['Ireland', 'United Kingdom', 'Germany', 'France', 'United States']
df_filtered = df[df['Country Name'].isin(countries)]

# %%
df_filtered = df_filtered.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code'])
